# %%
# 绘制简单的折线图
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares, linewidth = 3)

ax.set_title("squares", fontsize=24)
ax.set_xlabel("value", fontsize = 14)
ax.set_ylabel("squares of the values", fontsize=14)

ax.tick_params(axis='both', labelsize=14)

# %%
# 矫正上面错误的输出
input_values = [1, 2, 3, 4, 5] # 新添加
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(input_values, squares, linewidth = 3) # 新添加

ax.set_title("squares", fontsize=24)
ax.set_xlabel("value", fontsize = 14)
ax.set_ylabel("squares of the values", fontsize=14)

ax.tick_params(axis='both', labelsize=14)

# %%
# 内置样式
input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]
plt.style.use('seaborn') # 选择内饰
fig, ax = plt.subplots()
ax.plot(input_values, squares, linewidth = 3) 

ax.set_title("squares", fontsize=24)
ax.set_xlabel("value", fontsize = 14)
ax.set_ylabel("squares of the values", fontsize=14)

ax.tick_params(axis='both', labelsize=14)

# %%
# 使用scatter
x_values = range(1, 100)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=10)

ax.set_title("squares", fontsize=24)
ax.set_xlabel("value", fontsize = 14)
ax.set_ylabel("squares of the values", fontsize=14)
ax.tick_params(axis='both',  which ='major', labelsize=14)

# %%
# 使用颜色映射
x_values = range(1, 100)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10) #一个颜色的渐变

ax.set_title("squares", fontsize=24)
ax.set_xlabel("value", fontsize = 14)
ax.set_ylabel("squares of the values", fontsize=14)
ax.tick_params(axis='both',  which ='major', labelsize=14)
